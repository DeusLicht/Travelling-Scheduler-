# %% [markdown]
# # Planning a Trip Across Mumbai using Unsupervised Learning: Geo-Location Clustering

# %% [markdown]
# ## Preparing the dataset

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup as Soup

# %%
map_kml = "Travel.kml"
with open('Travel.kml') as data:
    kml_soup = Soup(data, 'lxml-xml')
coord = kml_soup.find_all('coordinates')
coord_list=[]
for x in coord:
    coord_list.append(str(x))
#coord_list

name = kml_soup.find_all('name')
name_list = []
for x in name:
    name_list.append(str(x))

# %%
cor_col = ['Longitude', 'Latitude', 'Landmark']
df_col = pd.DataFrame(columns = cor_col)
for i, j in zip(range(len(coord_list)), range(2, len(name_list))):
    itm = coord_list[i]
    string_split = itm.split(',')
    #print(string_split[0][24:])
    cor1 = float(string_split[0][24:])
    cor2 = float(string_split[1])
    cor3 = name_list[j][6:-7]
    df_col.loc[i] = [cor1, cor2, cor3]

# %%
df_col
# Out:
#     Longitude   Latitude                            Landmark
# 0   72.860127  19.000668                 Sewri Mangrove Park
# 1   72.861633  18.995574                     Lalbaugcha Raja
# 2   72.835874  18.990991                Nehru Science Centre
# 3   72.818873  18.990791                   Nehru Planetarium
# 4   72.814797  18.990059                     Haji Ali Dargah
# 5   72.808915  18.982728            Shree Mahalakshmi Temple
# 6   72.806366  18.977327                       Malabar Point
# 7   72.793990  18.941096                    Tower of Silence
# 8   72.807148  18.961818              Mumbai Chowpatty Beach
# 9   72.813882  18.954749  Nariman Point, Mumbai, Maharashtra
# 10  72.818597  18.925666             The Mumbai friend tower
# 11  72.810169  18.916724                         Prongs Reef
# 12  72.809928  18.893997                         Oyster Rock
# 13  72.827373  18.902382             Gateway Of India Mumbai
# 14  72.834654  18.921984                  Mumbai Cruise Pirs
# 15  72.843845  18.930641                        Marine Drive
# 16  72.823220  18.933118             Wankhede Stadium Mumbai
# 17  72.825764  18.938853                   Cross Island View
# 18  72.851741  18.948104                          Worli Fort
# 19  72.816800  19.023712               Bandra Worli Sea Link
# 20  72.814780  19.026613                         Bandra Fort
# 21  72.818359  19.041889                     Bandra Sea View
# 22  72.821968  19.061267                           Sion Fort
# 23  72.867682  19.046592                          Cubic Mall
# 24  72.903145  19.045433                Siddhivinayak Temple
# 25  72.869919  19.043203          Phoenix Marketcity, Mumbai
# 26  72.888977  19.086379                          Juhu Beach
# 27  72.826448  19.097419                       Infiniti Mall
# 28  72.830906  19.141213                      Madh Mangroves
# 29  72.797175  19.156824                       NNP Waterfall
# 30  72.886964  19.177672                       Kanheri Caves
# 31  72.906850  19.205851                         R City Mall
# 32  72.916394  19.099685                        Sunset Point
# 33  72.985586  19.094029                      Mahakali Caves
# 34  72.873174  19.130080             Movietime: The Hub Mall
# 35  72.856324  19.154774         Sanjay Gandhi National Park
# 36  72.918178  19.228809          Tigers Zone. National Park
# 37  72.925095  19.257601                     Jamdar Pada Dam
# 38  72.802213  19.256596                  Panju island beach
# 39  72.841675  19.338089    Bird Watching Area, Bhandup West
# 40  72.964628  19.141906                Kokanipada Waterfall
# 41  72.957849  19.239723                    Suraj Water Park
# 42  72.970666  19.254564      Ovalekar Wadi Butterfly Garden
# 43  72.955400  19.270073                          Vihar Lake
# 44  72.901658  19.154056                     Sarsole Boating
# 45  73.001150  19.049608              Nerul's Flamingo Point
# 46  73.006015  19.016570           Kharghar Hills View Point
# 47  73.047118  19.049426               Parsik Mountain Range

# %%
fig = plt.figure(figsize=(16,10))
plt.scatter(df_col['Longitude'], df_col['Latitude'], c = 'blue', s = 100)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('Scatter plot of Landmarks to Travel', fontsize=14)
plt.show()

# %%
X = df_col[['Longitude','Latitude']].values

# %% [markdown]
# ## Mini Batch K-Means Clustering: Eucliedian Distance

# %%
from sklearn.cluster import MiniBatchKMeans
km = MiniBatchKMeans(n_clusters=14, random_state=1 )
Km_pred = km.fit_predict(X)

# %%
Km_pred
# Out:
# array([ 4,  4,  4,  7,  7,  7,  7,  7,  7,  7,  1,  1,  1,  1,  1,  1,  1,
#         1,  1,  9,  9,  9,  9, 10, 10, 10, 10,  0,  0,  0, 11,  5, 10,  3,
#        11, 11,  5,  5,  6, 13,  3,  2,  2,  2, 11, 12, 12,  8])

# %%
Km_schedule = pd.concat([df_col.reset_index(), pd.DataFrame({'Cluster':Km_pred})], axis=1)
#days
Km_schedule.drop("index", axis = 1, inplace = True)

# %%
cond_list = [
    Km_schedule['Cluster'] == 0,
    Km_schedule['Cluster'] == 1,
    Km_schedule['Cluster'] == 2,
    Km_schedule['Cluster'] == 3,
    Km_schedule['Cluster'] == 4,
    Km_schedule['Cluster'] == 5,
    Km_schedule['Cluster'] == 6,
    Km_schedule['Cluster'] == 7,
    Km_schedule['Cluster'] == 8,
    Km_schedule['Cluster'] == 9,
    Km_schedule['Cluster'] == 10,
    Km_schedule['Cluster'] == 11,
    Km_schedule['Cluster'] == 12,
    Km_schedule['Cluster'] == 13,
]
options = ['Week 1 Sun', 'Week 1 Mon', 'Week 1 Tues', 'Week 1 Wed', 'Week 1 Thurs', 'Week 1 Fri', 'Week 1 Sat', 
           'Week 2 Sun', 'Week 2 Mon', 'Week 2 Tues', 'Week 2 Wed', 'Week 2 Thurs', 'Week 2 Fri', 'Week 2 Sat']
Km_schedule['Schedule'] = np.select(cond_list, options, default = 'black')

# %%
Km_schedule.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                            Landmark  Cluster  \
# 28  72.830906  19.141213                      Madh Mangroves        0
# 27  72.826448  19.097419                       Infiniti Mall        0
# 29  72.797175  19.156824                       NNP Waterfall        0
# 15  72.843845  18.930641                        Marine Drive        1
# 14  72.834654  18.921984                  Mumbai Cruise Pirs        1
# 13  72.827373  18.902382             Gateway Of India Mumbai        1
# 12  72.809928  18.893997                         Oyster Rock        1
# 11  72.810169  18.916724                         Prongs Reef        1
# 10  72.818597  18.925666             The Mumbai friend tower        1
# 18  72.851741  18.948104                          Worli Fort        1
# 17  72.825764  18.938853                   Cross Island View        1
# 16  72.823220  18.933118             Wankhede Stadium Mumbai        1
# 43  72.955400  19.270073                          Vihar Lake        2
# 42  72.970666  19.254564      Ovalekar Wadi Butterfly Garden        2
# 41  72.957849  19.239723                    Suraj Water Park        2
# 40  72.964628  19.141906                Kokanipada Waterfall        3
# 33  72.985586  19.094029                      Mahakali Caves        3
# 0   72.860127  19.000668                 Sewri Mangrove Park        4
# 2   72.835874  18.990991                Nehru Science Centre        4
# 1   72.861633  18.995574                     Lalbaugcha Raja        4
# 37  72.925095  19.257601                     Jamdar Pada Dam        5
# 36  72.918178  19.228809          Tigers Zone. National Park        5
# 31  72.906850  19.205851                         R City Mall        5
# 38  72.802213  19.256596                  Panju island beach        6
# 8   72.807148  18.961818              Mumbai Chowpatty Beach        7
# 7   72.793990  18.941096                    Tower of Silence        7
# 6   72.806366  18.977327                       Malabar Point        7
# 5   72.808915  18.982728            Shree Mahalakshmi Temple        7
# 4   72.814797  18.990059                     Haji Ali Dargah        7
# 3   72.818873  18.990791                   Nehru Planetarium        7
# 9   72.813882  18.954749  Nariman Point, Mumbai, Maharashtra        7
# 47  73.047118  19.049426               Parsik Mountain Range        8
# 22  72.821968  19.061267                           Sion Fort        9
# 21  72.818359  19.041889                     Bandra Sea View        9
# 20  72.814780  19.026613                         Bandra Fort        9
# 19  72.816800  19.023712               Bandra Worli Sea Link        9
# 32  72.916394  19.099685                        Sunset Point       10
# 26  72.888977  19.086379                          Juhu Beach       10
# 25  72.869919  19.043203          Phoenix Marketcity, Mumbai       10
# 24  72.903145  19.045433                Siddhivinayak Temple       10
# 23  72.867682  19.046592                          Cubic Mall       10
# 34  72.873174  19.130080             Movietime: The Hub Mall       11
# 35  72.856324  19.154774         Sanjay Gandhi National Park       11
# 44  72.901658  19.154056                     Sarsole Boating       11
# 30  72.886964  19.177672                       Kanheri Caves       11
# 46  73.006015  19.016570           Kharghar Hills View Point       12
# 45  73.001150  19.049608              Nerul's Flamingo Point       12
# 39  72.841675  19.338089    Bird Watching Area, Bhandup West       13
#
#         Schedule
# 28    Week 1 Sun
# 27    Week 1 Sun
# 29    Week 1 Sun
# 15    Week 1 Mon
# 14    Week 1 Mon
# 13    Week 1 Mon
# 12    Week 1 Mon
# 11    Week 1 Mon
# 10    Week 1 Mon
# 18    Week 1 Mon
# 17    Week 1 Mon
# 16    Week 1 Mon
# 43   Week 1 Tues
# 42   Week 1 Tues
# 41   Week 1 Tues
# 40    Week 1 Wed
# 33    Week 1 Wed
# 0   Week 1 Thurs
# 2   Week 1 Thurs
# 1   Week 1 Thurs
# 37    Week 1 Fri
# 36    Week 1 Fri
# 31    Week 1 Fri
# 38    Week 1 Sat
# 8     Week 2 Sun
# 7     Week 2 Sun
# 6     Week 2 Sun
# 5     Week 2 Sun
# 4     Week 2 Sun
# 3     Week 2 Sun
# 9     Week 2 Sun
# 47    Week 2 Mon
# 22   Week 2 Tues
# 21   Week 2 Tues
# 20   Week 2 Tues
# 19   Week 2 Tues
# 32    Week 2 Wed
# 26    Week 2 Wed
# 25    Week 2 Wed
# 24    Week 2 Wed
# 23    Week 2 Wed
# 34  Week 2 Thurs
# 35  Week 2 Thurs
# 44  Week 2 Thurs
# 30  Week 2 Thurs
# 46    Week 2 Fri
# 45    Week 2 Fri
# 39    Week 2 Sat

# %%
colormap = plt.cm.rainbow
normalize = matplotlib.colors.BoundaryNorm(np.arange(0,14,1), colormap.N)
fig = plt.figure(figsize=(16,10))
plt.scatter(Km_schedule['Longitude'], Km_schedule['Latitude'], c = Km_schedule['Cluster'], cmap = colormap, norm= normalize, s = 100)
plt.colorbar(ticks=np.linspace(0,13,14))
centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=1, marker = "x");
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering (n_clusters=14)', fontsize=14)
plt.show()

# %% [markdown]
# ## Agglomerative Clustering: Manhattan Distance

# %%
#AgglomerativeClustering (Manhattan Distance)
from sklearn.cluster import AgglomerativeClustering
Aggl_C = AgglomerativeClustering(n_clusters=14, affinity = 'manhattan' , linkage = 'average')
Agg_pred = Aggl_C.fit_predict(X)

# %%
AgC_schedule= pd.concat([df_col.reset_index(), pd.DataFrame({'Cluster':Agg_pred})], axis=1)
#days
AgC_schedule.drop("index", axis = 1, inplace = True)

# %%
cond_list = [
    AgC_schedule['Cluster'] == 0,
    AgC_schedule['Cluster'] == 1,
    AgC_schedule['Cluster'] == 2,
    AgC_schedule['Cluster'] == 3,
    AgC_schedule['Cluster'] == 4,
    AgC_schedule['Cluster'] == 5,
    AgC_schedule['Cluster'] == 6,
    AgC_schedule['Cluster'] == 7,
    AgC_schedule['Cluster'] == 8,
    AgC_schedule['Cluster'] == 9,
    AgC_schedule['Cluster'] == 10,
    AgC_schedule['Cluster'] == 11,
    AgC_schedule['Cluster'] == 12,
    AgC_schedule['Cluster'] == 13,
]
options = ['Week 1 Sun', 'Week 1 Mon', 'Week 1 Tues', 'Week 1 Wed', 'Week 1 Thurs', 'Week 1 Fri', 'Week 1 Sat', 
           'Week 2 Sun', 'Week 2 Mon', 'Week 2 Tues', 'Week 2 Wed', 'Week 2 Thurs', 'Week 2 Fri', 'Week 2 Sat']
AgC_schedule['Schedule'] = np.select(cond_list, options, default = 'black')

# %%
AgC_schedule.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                            Landmark  Cluster  \
# 27  72.826448  19.097419                       Infiniti Mall        0
# 22  72.821968  19.061267                           Sion Fort        0
# 21  72.818359  19.041889                     Bandra Sea View        0
# 20  72.814780  19.026613                         Bandra Fort        0
# 19  72.816800  19.023712               Bandra Worli Sea Link        0
# 0   72.860127  19.000668                 Sewri Mangrove Park        1
# 25  72.869919  19.043203          Phoenix Marketcity, Mumbai        1
# 24  72.903145  19.045433                Siddhivinayak Temple        1
# 23  72.867682  19.046592                          Cubic Mall        1
# 1   72.861633  18.995574                     Lalbaugcha Raja        1
# 47  73.047118  19.049426               Parsik Mountain Range        2
# 45  73.001150  19.049608              Nerul's Flamingo Point        2
# 46  73.006015  19.016570           Kharghar Hills View Point        2
# 32  72.916394  19.099685                        Sunset Point        3
# 26  72.888977  19.086379                          Juhu Beach        3
# 44  72.901658  19.154056                     Sarsole Boating        4
# 35  72.856324  19.154774         Sanjay Gandhi National Park        4
# 34  72.873174  19.130080             Movietime: The Hub Mall        4
# 30  72.886964  19.177672                       Kanheri Caves        4
# 28  72.830906  19.141213                      Madh Mangroves        4
# 10  72.818597  18.925666             The Mumbai friend tower        5
# 11  72.810169  18.916724                         Prongs Reef        5
# 18  72.851741  18.948104                          Worli Fort        5
# 17  72.825764  18.938853                   Cross Island View        5
# 16  72.823220  18.933118             Wankhede Stadium Mumbai        5
# 15  72.843845  18.930641                        Marine Drive        5
# 14  72.834654  18.921984                  Mumbai Cruise Pirs        5
# 13  72.827373  18.902382             Gateway Of India Mumbai        5
# 12  72.809928  18.893997                         Oyster Rock        5
# 43  72.955400  19.270073                          Vihar Lake        6
# 42  72.970666  19.254564      Ovalekar Wadi Butterfly Garden        6
# 41  72.957849  19.239723                    Suraj Water Park        6
# 37  72.925095  19.257601                     Jamdar Pada Dam        6
# 38  72.802213  19.256596                  Panju island beach        7
# 39  72.841675  19.338089    Bird Watching Area, Bhandup West        8
# 6   72.806366  18.977327                       Malabar Point        9
# 9   72.813882  18.954749  Nariman Point, Mumbai, Maharashtra        9
# 7   72.793990  18.941096                    Tower of Silence        9
# 8   72.807148  18.961818              Mumbai Chowpatty Beach        9
# 2   72.835874  18.990991                Nehru Science Centre        9
# 3   72.818873  18.990791                   Nehru Planetarium        9
# 4   72.814797  18.990059                     Haji Ali Dargah        9
# 5   72.808915  18.982728            Shree Mahalakshmi Temple        9
# 29  72.797175  19.156824                       NNP Waterfall       10
# 31  72.906850  19.205851                         R City Mall       11
# 36  72.918178  19.228809          Tigers Zone. National Park       11
# 40  72.964628  19.141906                Kokanipada Waterfall       12
# 33  72.985586  19.094029                      Mahakali Caves       13
#
#         Schedule
# 27    Week 1 Sun
# 22    Week 1 Sun
# 21    Week 1 Sun
# 20    Week 1 Sun
# 19    Week 1 Sun
# 0     Week 1 Mon
# 25    Week 1 Mon
# 24    Week 1 Mon
# 23    Week 1 Mon
# 1     Week 1 Mon
# 47   Week 1 Tues
# 45   Week 1 Tues
# 46   Week 1 Tues
# 32    Week 1 Wed
# 26    Week 1 Wed
# 44  Week 1 Thurs
# 35  Week 1 Thurs
# 34  Week 1 Thurs
# 30  Week 1 Thurs
# 28  Week 1 Thurs
# 10    Week 1 Fri
# 11    Week 1 Fri
# 18    Week 1 Fri
# 17    Week 1 Fri
# 16    Week 1 Fri
# 15    Week 1 Fri
# 14    Week 1 Fri
# 13    Week 1 Fri
# 12    Week 1 Fri
# 43    Week 1 Sat
# 42    Week 1 Sat
# 41    Week 1 Sat
# 37    Week 1 Sat
# 38    Week 2 Sun
# 39    Week 2 Mon
# 6    Week 2 Tues
# 9    Week 2 Tues
# 7    Week 2 Tues
# 8    Week 2 Tues
# 2    Week 2 Tues
# 3    Week 2 Tues
# 4    Week 2 Tues
# 5    Week 2 Tues
# 29    Week 2 Wed
# 31  Week 2 Thurs
# 36  Week 2 Thurs
# 40    Week 2 Fri
# 33    Week 2 Sat

# %%
from sklearn.neighbors import NearestCentroid
clf = NearestCentroid(metric = 'manhattan')
clf.fit(X, Agg_pred)
# Out:
# NearestCentroid(metric='manhattan', shrink_threshold=None)

# %%
colormap = plt.cm.rainbow
normalize = matplotlib.colors.BoundaryNorm(np.arange(0,14,1), colormap.N)
fig = plt.figure(figsize=(16,10))
plt.scatter(AgC_schedule['Longitude'], AgC_schedule['Latitude'], c = AgC_schedule['Cluster'], cmap = colormap, norm= normalize, s = 100)
plt.colorbar(ticks=np.linspace(0,13,14))
centers = clf.centroids_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=1 ,marker = 'x');
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('Agglomerative clustering (n_clusters=14)', fontsize=14)
plt.show()

# %% [markdown]
# ## Balanced Iterative Reducing and Clustering (BIRCH): Tree Structure

# %%
from sklearn.cluster import Birch
Bir_C = Birch(threshold=0.01, n_clusters=14)
Bir_pred = Bir_C.fit_predict(X)

# %%
Bir_pred
# Out:
# array([ 4,  4,  4,  4,  4, 12, 12, 12, 12, 12,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  1,  1,  1,  1,  5,  5,  5, 13,  1,  0,  0,  9, 11, 13,  3,
#         0,  0, 11,  6, 10,  8,  3,  6,  6,  6,  9,  2,  2,  2],
#       dtype=int64)

# %%
Bir_schedule= pd.concat([df_col.reset_index(), pd.DataFrame({'Cluster':Bir_pred})], axis=1)
#days
Bir_schedule.drop("index", axis = 1, inplace = True)

# %%
cond_list = [
    Bir_schedule['Cluster'] == 0,
    Bir_schedule['Cluster'] == 1,
    Bir_schedule['Cluster'] == 2,
    Bir_schedule['Cluster'] == 3,
    Bir_schedule['Cluster'] == 4,
    Bir_schedule['Cluster'] == 5,
    Bir_schedule['Cluster'] == 6,
    Bir_schedule['Cluster'] == 7,
    Bir_schedule['Cluster'] == 8,
    Bir_schedule['Cluster'] == 9,
    Bir_schedule['Cluster'] == 10,
    Bir_schedule['Cluster'] == 11,
    Bir_schedule['Cluster'] == 12,
    Bir_schedule['Cluster'] == 13,
]
options = ['Week 1 Sun', 'Week 1 Mon', 'Week 1 Tues', 'Week 1 Wed', 'Week 1 Thurs', 'Week 1 Fri', 'Week 1 Sat', 
           'Week 2 Sun', 'Week 2 Mon', 'Week 2 Tues', 'Week 2 Wed', 'Week 2 Thurs', 'Week 2 Fri', 'Week 2 Sat']
Bir_schedule['Schedule'] = np.select(cond_list, options, default = 'black')

# %%
Bir_schedule.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                            Landmark  Cluster  \
# 35  72.856324  19.154774         Sanjay Gandhi National Park        0
# 34  72.873174  19.130080             Movietime: The Hub Mall        0
# 29  72.797175  19.156824                       NNP Waterfall        0
# 28  72.830906  19.141213                      Madh Mangroves        0
# 27  72.826448  19.097419                       Infiniti Mall        1
# 22  72.821968  19.061267                           Sion Fort        1
# 21  72.818359  19.041889                     Bandra Sea View        1
# 20  72.814780  19.026613                         Bandra Fort        1
# 19  72.816800  19.023712               Bandra Worli Sea Link        1
# 47  73.047118  19.049426               Parsik Mountain Range        2
# 45  73.001150  19.049608              Nerul's Flamingo Point        2
# 46  73.006015  19.016570           Kharghar Hills View Point        2
# 40  72.964628  19.141906                Kokanipada Waterfall        3
# 33  72.985586  19.094029                      Mahakali Caves        3
# 0   72.860127  19.000668                 Sewri Mangrove Park        4
# 1   72.861633  18.995574                     Lalbaugcha Raja        4
# 2   72.835874  18.990991                Nehru Science Centre        4
# 3   72.818873  18.990791                   Nehru Planetarium        4
# 4   72.814797  18.990059                     Haji Ali Dargah        4
# 23  72.867682  19.046592                          Cubic Mall        5
# 24  72.903145  19.045433                Siddhivinayak Temple        5
# 25  72.869919  19.043203          Phoenix Marketcity, Mumbai        5
# 43  72.955400  19.270073                          Vihar Lake        6
# 42  72.970666  19.254564      Ovalekar Wadi Butterfly Garden        6
# 41  72.957849  19.239723                    Suraj Water Park        6
# 37  72.925095  19.257601                     Jamdar Pada Dam        6
# 14  72.834654  18.921984                  Mumbai Cruise Pirs        7
# 15  72.843845  18.930641                        Marine Drive        7
# 11  72.810169  18.916724                         Prongs Reef        7
# 16  72.823220  18.933118             Wankhede Stadium Mumbai        7
# 17  72.825764  18.938853                   Cross Island View        7
# 18  72.851741  18.948104                          Worli Fort        7
# 13  72.827373  18.902382             Gateway Of India Mumbai        7
# 10  72.818597  18.925666             The Mumbai friend tower        7
# 12  72.809928  18.893997                         Oyster Rock        7
# 39  72.841675  19.338089    Bird Watching Area, Bhandup West        8
# 30  72.886964  19.177672                       Kanheri Caves        9
# 44  72.901658  19.154056                     Sarsole Boating        9
# 38  72.802213  19.256596                  Panju island beach       10
# 31  72.906850  19.205851                         R City Mall       11
# 36  72.918178  19.228809          Tigers Zone. National Park       11
# 9   72.813882  18.954749  Nariman Point, Mumbai, Maharashtra       12
# 5   72.808915  18.982728            Shree Mahalakshmi Temple       12
# 6   72.806366  18.977327                       Malabar Point       12
# 8   72.807148  18.961818              Mumbai Chowpatty Beach       12
# 7   72.793990  18.941096                    Tower of Silence       12
# 32  72.916394  19.099685                        Sunset Point       13
# 26  72.888977  19.086379                          Juhu Beach       13
#
#         Schedule
# 35    Week 1 Sun
# 34    Week 1 Sun
# 29    Week 1 Sun
# 28    Week 1 Sun
# 27    Week 1 Mon
# 22    Week 1 Mon
# 21    Week 1 Mon
# 20    Week 1 Mon
# 19    Week 1 Mon
# 47   Week 1 Tues
# 45   Week 1 Tues
# 46   Week 1 Tues
# 40    Week 1 Wed
# 33    Week 1 Wed
# 0   Week 1 Thurs
# 1   Week 1 Thurs
# 2   Week 1 Thurs
# 3   Week 1 Thurs
# 4   Week 1 Thurs
# 23    Week 1 Fri
# 24    Week 1 Fri
# 25    Week 1 Fri
# 43    Week 1 Sat
# 42    Week 1 Sat
# 41    Week 1 Sat
# 37    Week 1 Sat
# 14    Week 2 Sun
# 15    Week 2 Sun
# 11    Week 2 Sun
# 16    Week 2 Sun
# 17    Week 2 Sun
# 18    Week 2 Sun
# 13    Week 2 Sun
# 10    Week 2 Sun
# 12    Week 2 Sun
# 39    Week 2 Mon
# 30   Week 2 Tues
# 44   Week 2 Tues
# 38    Week 2 Wed
# 31  Week 2 Thurs
# 36  Week 2 Thurs
# 9     Week 2 Fri
# 5     Week 2 Fri
# 6     Week 2 Fri
# 8     Week 2 Fri
# 7     Week 2 Fri
# 32    Week 2 Sat
# 26    Week 2 Sat

# %%
colormap = plt.cm.rainbow
normalize = matplotlib.colors.BoundaryNorm(np.arange(0,14,1), colormap.N)
fig = plt.figure(figsize=(16,10))
plt.scatter(Bir_schedule['Longitude'], Bir_schedule['Latitude'], c = Bir_schedule['Cluster'], cmap = colormap, norm= normalize, s = 100)
plt.colorbar(ticks=np.linspace(0,13,14))
centers = clf.centroids_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=1 ,marker = 'x');
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('BIRCH clustering (n_clusters=14)', fontsize=14)
plt.show()

# %% [markdown]
# ## Hierarchical Density-Based Spatial Clustering (HDBSCAN): Harvesine Distance

# %%
import hdbscan as hdb

# %%
radians = np.radians(X)
Hdbs_Clus = hdb.HDBSCAN(min_cluster_size=2, metric='haversine')
Hdbs_pred = Hdbs_Clus.fit_predict(X)

# %%
Hdbs_pred
# Out:
# array([ 9,  9, -1, 13, 13, 14, 14, -1, 10, 10, 11, 11, -1, -1, 12, 12, 11,
#        11, -1,  6,  6,  6,  6,  3,  3,  3,  4, -1,  2, -1,  7,  8,  4,  1,
#         2,  2,  8,  8,  0,  0,  1,  5,  5,  5,  7,  1,  1,  1],
#       dtype=int64)

# %%
Hdbs_schedule= pd.concat([df_col.reset_index(), pd.DataFrame({'Cluster':Hdbs_pred})], axis=1)
#days
Hdbs_schedule.drop("index", axis = 1, inplace = True)

# %%
cond_list = [
    Hdbs_schedule['Cluster'] == -1,
    Hdbs_schedule['Cluster'] == 0,
    Hdbs_schedule['Cluster'] == 1,
    Hdbs_schedule['Cluster'] == 2,
    Hdbs_schedule['Cluster'] == 3,
    Hdbs_schedule['Cluster'] == 4,
    Hdbs_schedule['Cluster'] == 5,
    Hdbs_schedule['Cluster'] == 6,
    Hdbs_schedule['Cluster'] == 7,
    Hdbs_schedule['Cluster'] == 8,
    Hdbs_schedule['Cluster'] == 9,
    Hdbs_schedule['Cluster'] == 10,
    Hdbs_schedule['Cluster'] == 11,
    Hdbs_schedule['Cluster'] == 12,
    Hdbs_schedule['Cluster'] == 13,
    Hdbs_schedule['Cluster'] == 14,
]
options = ['Noise', 'Week 1 Sun', 'Week 1 Mon', 'Week 1 Tues', 'Week 1 Wed', 'Week 1 Thurs', 'Week 1 Fri', 'Week 1 Sat', 
           'Week 2 Sun', 'Week 2 Mon', 'Week 2 Tues', 'Week 2 Wed', 'Week 2 Thurs', 'Week 2 Fri', 'Week 2 Sat', 'Week 3 Sun']
Hdbs_schedule['Schedule'] = np.select(cond_list, options, default = 'black')

# %%
Hdbs_schedule.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                            Landmark  Cluster  \
# 18  72.851741  18.948104                          Worli Fort       -1
# 27  72.826448  19.097419                       Infiniti Mall       -1
# 2   72.835874  18.990991                Nehru Science Centre       -1
# 13  72.827373  18.902382             Gateway Of India Mumbai       -1
# 12  72.809928  18.893997                         Oyster Rock       -1
# 7   72.793990  18.941096                    Tower of Silence       -1
# 29  72.797175  19.156824                       NNP Waterfall       -1
# 39  72.841675  19.338089    Bird Watching Area, Bhandup West        0
# 38  72.802213  19.256596                  Panju island beach        0
# 47  73.047118  19.049426               Parsik Mountain Range        1
# 40  72.964628  19.141906                Kokanipada Waterfall        1
# 45  73.001150  19.049608              Nerul's Flamingo Point        1
# 46  73.006015  19.016570           Kharghar Hills View Point        1
# 33  72.985586  19.094029                      Mahakali Caves        1
# 34  72.873174  19.130080             Movietime: The Hub Mall        2
# 28  72.830906  19.141213                      Madh Mangroves        2
# 35  72.856324  19.154774         Sanjay Gandhi National Park        2
# 25  72.869919  19.043203          Phoenix Marketcity, Mumbai        3
# 24  72.903145  19.045433                Siddhivinayak Temple        3
# 23  72.867682  19.046592                          Cubic Mall        3
# 26  72.888977  19.086379                          Juhu Beach        4
# 32  72.916394  19.099685                        Sunset Point        4
# 43  72.955400  19.270073                          Vihar Lake        5
# 42  72.970666  19.254564      Ovalekar Wadi Butterfly Garden        5
# 41  72.957849  19.239723                    Suraj Water Park        5
# 20  72.814780  19.026613                         Bandra Fort        6
# 21  72.818359  19.041889                     Bandra Sea View        6
# 22  72.821968  19.061267                           Sion Fort        6
# 19  72.816800  19.023712               Bandra Worli Sea Link        6
# 44  72.901658  19.154056                     Sarsole Boating        7
# 30  72.886964  19.177672                       Kanheri Caves        7
# 37  72.925095  19.257601                     Jamdar Pada Dam        8
# 31  72.906850  19.205851                         R City Mall        8
# 36  72.918178  19.228809          Tigers Zone. National Park        8
# 1   72.861633  18.995574                     Lalbaugcha Raja        9
# 0   72.860127  19.000668                 Sewri Mangrove Park        9
# 8   72.807148  18.961818              Mumbai Chowpatty Beach       10
# 9   72.813882  18.954749  Nariman Point, Mumbai, Maharashtra       10
# 10  72.818597  18.925666             The Mumbai friend tower       11
# 11  72.810169  18.916724                         Prongs Reef       11
# 16  72.823220  18.933118             Wankhede Stadium Mumbai       11
# 17  72.825764  18.938853                   Cross Island View       11
# 14  72.834654  18.921984                  Mumbai Cruise Pirs       12
# 15  72.843845  18.930641                        Marine Drive       12
# 4   72.814797  18.990059                     Haji Ali Dargah       13
# 3   72.818873  18.990791                   Nehru Planetarium       13
# 5   72.808915  18.982728            Shree Mahalakshmi Temple       14
# 6   72.806366  18.977327                       Malabar Point       14
#
#         Schedule
# 18         Noise
# 27         Noise
# 2          Noise
# 13         Noise
# 12         Noise
# 7          Noise
# 29         Noise
# 39    Week 1 Sun
# 38    Week 1 Sun
# 47    Week 1 Mon
# 40    Week 1 Mon
# 45    Week 1 Mon
# 46    Week 1 Mon
# 33    Week 1 Mon
# 34   Week 1 Tues
# 28   Week 1 Tues
# 35   Week 1 Tues
# 25    Week 1 Wed
# 24    Week 1 Wed
# 23    Week 1 Wed
# 26  Week 1 Thurs
# 32  Week 1 Thurs
# 43    Week 1 Fri
# 42    Week 1 Fri
# 41    Week 1 Fri
# 20    Week 1 Sat
# 21    Week 1 Sat
# 22    Week 1 Sat
# 19    Week 1 Sat
# 44    Week 2 Sun
# 30    Week 2 Sun
# 37    Week 2 Mon
# 31    Week 2 Mon
# 36    Week 2 Mon
# 1    Week 2 Tues
# 0    Week 2 Tues
# 8     Week 2 Wed
# 9     Week 2 Wed
# 10  Week 2 Thurs
# 11  Week 2 Thurs
# 16  Week 2 Thurs
# 17  Week 2 Thurs
# 14    Week 2 Fri
# 15    Week 2 Fri
# 4     Week 2 Sat
# 3     Week 2 Sat
# 5     Week 3 Sun
# 6     Week 3 Sun

# %%
colormap = plt.cm.gnuplot
#normalize = matplotlib.colors.BoundaryNorm(np.arange(0,14,1), colormap.N)
fig = plt.figure(figsize=(16,10))
plt.scatter(Hdbs_schedule['Longitude'], Hdbs_schedule['Latitude'], c = Hdbs_schedule['Cluster'], cmap = colormap, s = 100)
plt.colorbar(ticks=np.linspace(-1,14,16))
centers = clf.centroids_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=1 ,marker = 'x');
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('HDBSCAN clustering', fontsize=14)
plt.show()
